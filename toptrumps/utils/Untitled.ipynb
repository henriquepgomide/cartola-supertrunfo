# %%
import os
import sys
os.chdir('/home/henrique/Downloads/pixelator-1.0.5-linux-x64/pixelator-linux-x64/')

# %%
exec = "/home/henrique/Downloads/pixelator-1.0.5-linux-x64/pixelator-linux-x64/_pixelator_cmd.exe"
pars = "--pixelate 2 --colors 24 --palette_mode adaptive --enhance 2 --smooth 2 --smooth_iterations 1 --refine_edges 250 --stroke none --stroke_opacity 1 --stroke_on_colors_diff 0 --background '#00000000'    --palette_file ''"

input_prefix = "/home/henrique/cartolapfc/cartola/static/images/players-photos/2019/"
output_prefix = "/home/henrique/cartolapfc/cartola/static/images/super-pfc/"

list_of_pictures = os.listdir('/home/henrique/cartolapfc/cartola/static/images/players-photos/2019/')

# %%
for i in range(len(list_of_pictures)):
    input = input_prefix + list_of_pictures[i]
    output = output_prefix + list_of_pictures[i]
    
    os.system("{0} {1} {2} {3}".format(exec, input, output, pars))
# Out:
# File 78151.png was pixelated.
# File 83772.png was pixelated.
# File 81682.png was pixelated.
# File 90933.png was pixelated.
# File 97780.png was pixelated.
# File 104089.png was pixelated.
# File 87258.png was pixelated.
# File 71787.png was pixelated.
# File 71571.png was pixelated.
# File 90285.png was pixelated.
# File 72033.png was pixelated.
# File 104257.png was pixelated.
# File 72168.png was pixelated.
# File 42234.png was pixelated.
# File 39572.png was pixelated.
# File 105636.png was pixelated.
# File 102997.png was pixelated.
# File 89150.png was pixelated.
# File 100840.png was pixelated.
# File 50459.png was pixelated.
# File 95466.png was pixelated.
# File 104328.png was pixelated.
# File 75295.png was pixelated.
# File 104333.png was pixelated.
# File 78605.png was pixelated.
# File 94495.png was pixelated.
# File 103700.png was pixelated.
# File 92146.png was pixelated.
# File 104634.png was pixelated.
# File 100065.png was pixelated.
# ...
